# %%
from google import genai

# %%
client = genai.Client(api_key="")

# %%
response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="""
Você irá receber um dicionário de produtos, gostaria que você me criasse um texto chamativo para ser compartilhada em um grupo de telegram de promoções.
{'itemId': 22394976954, 'productName': '2 Bermuda Compressão com Bolso Interno para Celular', 'productLink': 'https://shopee.com.br/product/1370479894/22394976954', 'offerLink': 'https://s.shopee.com.br/3LO8svJkCh', 'imageUrl': 'https://cf.shopee.com.br/file/br-11134207-820l9-moa2j440vjev96', 'priceMin': '59.9', 'priceMax': '59.9', 'priceDiscountRate': 0, 'sales': 0, 'ratingStar': '0', 'commissionRate': '0.7', 'sellerCommissionRate': '0.67', 'shopeeCommissionRate': '0.03', 'commission': '41.93', 'shopId': 1370479894, 'shopName': 'JS CONFECÇÕES E UNIFORMES ', 'shopType': [2], 'periodStartTime': 1778872591, 'periodEndTime': 1782874799} 
{'itemId': 49655807488, 'productName': 'Kit 10 Capas Bolsas Prova Dagua Impermeavel Universal Transparente Celular Protegido', 'productLink': 'https://shopee.com.br/product/427918541/49655807488', 'offerLink': 'https://s.shopee.com.br/3B4igcKNXg', 'imageUrl': 'https://cf.shopee.com.br/file/br-11134207-820lu-mowqcv65v11c5a', 'priceMin': '39.99', 'priceMax': '39.99', 'priceDiscountRate': 34, 'sales': 0, 'ratingStar': '5', 'commissionRate': '0.66', 'sellerCommissionRate': '0.63', 'shopeeCommissionRate': '0.03', 'commission': '26.3934', 'shopId': 427918541, 'shopName': 'DakiHappy', 'shopType': [2], 'periodStartTime': 1777258800, 'periodEndTime': 1782874799} 
Faça uma piada e um texto com Foco em Custo-Benefício e Praticidade. Lembrando, quero apenas a mensagem final, sem explicações adicionais!
Observação: Se receber mais de um dicionário você deve criar um texto para cada.
"""
)

# %%
print(response.text)
# Out:
# 🏃‍♂️ **CORRER SEGURANDO O CELULAR? SÓ SE FOR PARA TREINAR O MALABARISMO!** 🤣
#
# Se exercitar segurando o celular é igual a tentar equilibrar um prato de sopa na montanha-russa: uma hora vai dar ruim!
#
# Esqueça o perigo de derrubar o aparelho com esse **Kit de 2 Bermudas de Compressão**! Elas vêm com bolso interno projetado especificamente para o seu celular ficar firme, seguro e confortável enquanto você se movimenta. É o máximo da praticidade para os seus treinos!
#
# 💰 **Custo-Benefício Imbatível:** Você leva DUAS bermudas de alta qualidade por um preço que cabe no bolso!
# 🔥 Apenas **R$ 59,90** (O kit com 2!)
#
# 👉 Garanta o seu kit aqui: https://s.shopee.com.br/3LO8svJkCh
#
# ---
#
# 💦 **O SEU CELULAR NÃO SABE NADAR (E O ARROZ NÃO FAZ MILAGRE)!** 🍚📱😂
#
# A melhor utilidade do arroz é no prato com feijão, e não tentar ressuscitar celular que caiu na água!
#
# ...
